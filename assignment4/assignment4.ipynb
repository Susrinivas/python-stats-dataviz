# %% [markdown]
# <a href="https://colab.research.google.com/github/Susrinivas/python-stats-dataviz/blob/master/assignment4/assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
college_data = pd.read_csv('MERGED2017_18_PP.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
college_data.head(1)
# Out:
#    UNITID   OPEID  OPEID6                    INSTNM    CITY STABBR    ZIP  \
# 0  100654  100200    1002  Alabama A & M University  Normal     AL  35762
#
#    ACCREDAGENCY  INSTURL  NPCURL  ...  OMENRUP_PARTTIME_POOLED_SUPP  \
# 0           NaN      NaN     NaN  ...                           NaN
#
#    FTFTPCTPELL  FTFTPCTFLOAN  UG12MN   G12MN  SCUGFFN  POOLYRS_FTFTAIDPCT  \
# 0       0.7106        0.7418  5207.0  1185.0   1410.0                 NaN
#
#    FTFTPCTPELL_POOLED_SUPP  FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 0                      NaN                       NaN             NaN
#
# [1 rows x 1986 columns]

# %%
college_data['INSTNM'].count()
# Out:
# 7112

# %%
type(college_data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(college_data.columns)
# Out:
# 1986

# %%
college_data.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %%
college_data.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %%
college_data.sample(n=5)
# Out:
#       UNITID    OPEID  OPEID6  \
# 3327  220394  1070000   10700
# 5675  458502   267815    2678
# 4093  363147  2563000   25630
# 3077  214582  1099800   10998
# 446   122366  3010611   30106
#
#                                                  INSTNM       CITY STABBR  \
# 3327  Tennessee College of Applied Technology-Jacksboro  Jacksboro     TN
# 5675                 Bryant & Stratton College-Bayshore   Glendale     WI
# 4093    Raphael's School of Beauty Culture Inc-Alliance   Alliance     OH
# 3077               Pennsylvania Institute of Technology      Media     PA
# 446                   Golf Academy of America-San Diego   Carlsbad     CA
#
#              ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 3327       37757           NaN      NaN     NaN  ...
# 5675       53217           NaN      NaN     NaN  ...
# 4093       44601           NaN      NaN     NaN  ...
# 3077  19063-4098           NaN      NaN     NaN  ...
# 446        92008           NaN      NaN     NaN  ...
#
# ...

# %%
college_data_sm = college_data[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]

# %%
college_data_sm.head(5)
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %%
college_data['INSTNM'].head(10)
# Out:
# 0               Alabama A & M University
# 1    University of Alabama at Birmingham
# 2                     Amridge University
# 3    University of Alabama in Huntsville
# 4               Alabama State University
# 5              The University of Alabama
# 6      Central Alabama Community College
# 7                Athens State University
# 8        Auburn University at Montgomery
# 9                      Auburn University
# Name: INSTNM, dtype: object

# %%
college_data['INSTNM'].tail(10)
# Out:
# 7102    National Personal Training Institute of Cleveland
# 7103               Barber School of Pittsburgh - Ambridge
# 7104                   Arizona State University at Tucson
# 7105    Arizona State University - ASU Colleges at Lak...
# 7106          Arizona State University at The Gila Valley
# 7107                     Arizona State University at Yuma
# 7108    Bay Area Medical Academy - San Jose Satellite ...
# 7109             High Desert Medical College - Bakerfield
# 7110                                         BCI - Malden
# 7111                 HCI College - Fort Lauderdale Campus
# Name: INSTNM, dtype: object

# %%
college_data_sm.sample(n=10)
# Out:
#       UNITID                                             INSTNM          CITY  \
# 2139  186645                   Raritan Valley Community College    Branchburg
# 2190  188678         American Academy of Dramatic Arts-New York      New York
# 6556  488961            Ross Medical Education Center-Lafayette     Lafayette
# 4385  401250  Yo San University of Traditional Chinese Medicine   Los Angeles
# 4051  250027                          Laurel Business Institute     Uniontown
# 6412  486415           AMG School of Licensed Practical Nursing      Brooklyn
# 2733  204194                   Mount Vernon Nazarene University  Mount Vernon
# 1433  161299                             Maine Maritime Academy       Castine
# 171   107789                  Paul Mitchell the School-Arkansas  Fayetteville
# 1490  163657                  Prince George's Community College         Largo
#
#      STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# ...

# %%
c1 = college_data_sm[college_data_sm['INSTNM'].str.contains("maryland-baltimore county", case=False)]
c1
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %%
c2 = college_data_sm[college_data_sm['INSTNM'].str.contains("college park", case=False)]
c2
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %%
c3 = college_data_sm[college_data_sm['INSTNM'].str.contains("loyola university maryland", case=False)]
c3
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %%
c4 = college_data_sm[college_data_sm['INSTNM'].str.contains("johns hopkins", case=False)]
c4
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %%
df = c1.append(c2.append(c3.append(c4,ignore_index=True), ignore_index=True), ignore_index=True)

# %%
df
# Out:
#    UNITID                                   INSTNM          CITY STABBR  \
# 0  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1  163286      University of Maryland-College Park  College Park     MD
# 2  163046               Loyola University Maryland     Baltimore     MD
# 3  162928                 Johns Hopkins University     Baltimore     MD
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       21250    0.6021  11130.0        11518.0              NaN
# 1       20742    0.4450  29273.0        10399.0              NaN
# 2  21210-2699    0.7528   3903.0        47560.0              NaN
# 3  21218-2688    0.1254   5663.0        52170.0              NaN

# %%
df[df['TUITIONFEE_IN'] == df['TUITIONFEE_IN'].min()]
# Out:
#    UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1  163286  University of Maryland-College Park  College Park     MD  20742
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1     0.445  29273.0        10399.0              NaN

# %%
df[df['TUITIONFEE_IN'] == df['TUITIONFEE_IN'].max()]
# Out:
#    UNITID                    INSTNM       CITY STABBR         ZIP  ADM_RATE  \
# 3  162928  Johns Hopkins University  Baltimore     MD  21218-2688    0.1254
#
#      UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 3  5663.0        52170.0              NaN

# %%
print("mean value of tution fee: ",df['TUITIONFEE_IN'].mean())
# Out:
# mean value of tution fee:  30411.75

# %%
college_data.head(3)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# 1                           NaN       0.4009        0.5488  13308.0  9888.0
# 2                           NaN       0.5000        0.5000    431.0   437.0
#
#    SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 0   1410.0                 NaN                      NaN
# ...

# %%
college_data_3 = college_data_sm[college_data_sm['STABBR'].isin(['DE','MD','PA','VA','DC'])]

# %%
college_data_3
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# ...        ...                                                ...
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7084  47503303      Relay Graduate School of Education - Delaware
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7094  47503313  Relay Graduate School of Education - Washingto...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 634          Lewes     DE      19958       NaN     59.0            NaN
# ...

# %%
college_data_3.to_csv('Five_States_Colleges.csv', index=False)
